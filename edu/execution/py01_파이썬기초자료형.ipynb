# %% [markdown]
# # 1. 파이썬기초

# %% [markdown]
# ## 1.1 Print 기초

# %%
# 문자
print("주피터랩이 처음이에요.")
#숫자
print(1234)
# Out:
# 주피터랩이 처음이에요.
# 1234

# %%
# 문자 + 문자
print("주피터랩이 " + "처음이에요.")
# 숫자 + 숫자
print(1234+2345)
# Out:
# 주피터랩이 처음이에요.
# 3579

# %%
# 문자 + 문자(숫자X)
print("주피터랩이 " + "1234")
# Out:
# 주피터랩이 1234

# %% [markdown]
# **문자 + 숫자에러**
#
# ![image.png](attachment:212376d7-c385-48e2-8ca1-616c98c1880a.png)

# %%
# 문자 x 숫자 = 반복
print("안녕" * 5, end='')
# Out:
# 안녕안녕안녕안녕안녕

# %% [markdown]
# <hr/>

# %%
print("=" * 20, end='') # 마지막에 end='' 를 이용하여 개행제거
print("안녕" * 5, end='')
print("=" * 20, end='')
# Out:
# ====================안녕안녕안녕안녕안녕====================

# %%
# print 심화2
print("안녕","하시","겠습니까","?")
print("안녕","하시","겠습니까","?", sep='-')
print(1, 2, 3, 4, 5, sep='')

# %% [markdown]
# <hr/>

# %%
# print 응용１
import time as t
print("안녕")
t.sleep(1)
print("하시렵니까")
t.sleep(1)
print("?")
# Out:
# 안녕
# 하시렵니까
# ?

# %%
# print 응용２
import time as t
print("기대하세요", end='\r') # 캐리지 리턴
t.sleep(1.5)
print("드디어~~", end='\r') # 캐리지 리턴
t.sleep(1.5)
print("개봉합니다!")

##

# %% [markdown]
# ## 1.2 숫자형

# %%
# 정수형
a = 123
b = -321
c = 0
print(a)
print(b)
print(c)
# Out:
# 123
# -321
# 0

# %%
# 실수형
aa = 3.141592
bb = -12.34
cc = 3.14E10
dd = 3.14E-10
ee = 2**10
print(aa)
print(bb)
print(cc)
print(dd)
print(ee)
# Out:
# 3.141592
# -12.34
# 31400000000.0
# 3.14e-10
# 1024

# %%
# 2진수(bin)
aaa = 0b11
# 8진수(oct)
bbb = 0o11
# 16진수(hex)
ccc = 0x1f
print(aaa)
print(bbb)
print(ccc)
# Out:
# 3
# 9
# 31

# %%
ss = 2
dd = 10
print(ss ** dd)
# Out:
# 1024

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>항목</th>
# <th>파이썬 사용 예</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>정수</td>
# <td>123, -345, 0</td>
# </tr>
# <tr>
# <td>실수</td>
# <td>123.45, -1234.5, 3.4e10</td>
# </tr>
# <tr>
# <td>8진수</td>
# <td>0o34, 0o25</td>
# </tr>
# <tr>
# <td>16진수</td>
# <td>0x2A, 0xFF</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## 1.3 사칙연산

# %%
# 사칙연산 예
sa = 77
san = 13
print('덧셈:', sa + san)
print('뺄셈:', sa - san)
print('곱셈:', sa * san)
print('나눗셈:', sa / san)
print('몫:', sa // san)
print('나머지:', sa % san)
print('승:', sa ** san)
# Out:
# 덧셈: 90
# 뺄셈: 64
# 곱셈: 1001
# 나눗셈: 5.923076923076923
# 몫: 5
# 나머지: 12
# 승: 3344871416191195940889917

# %%
print((10*18**2) + (2*11))
# Out:
# 3262

# %%
# 복합연산자
a = 1 # 초기값
a += 1 # a=a+1
print(a)
# Out:
# 2

# %%
a += 1
print(a)
# Out:
# 3

# %%
! ls
# Out:
# disp.py  jupy.sh  py01.ipynb  test.py  test.txt  test2.txt  venv

# %%
! cat test.py
# Out:
# print("테스트입니다")
# a = 123
# b = 234
# print(a)
# b

# %% [markdown]
# ## 1.4 문자열 자료형

# %%
str1 = "안녕" + "하세요"
str2 = "안녕하세요 \"홍길동\" 이라고 합니다"
str3 = '안녕하세요 "홍길동" 이라고 합니다'
str4 = """1.
여러 줄을
작성합니다."""
str5 = '''2.
여러 줄을
작성합니다.'''
str6 = "3.\n여러 줄을\n작성합니다"
print(str1)
print(str2)
print(str3)
print(str4)
print(str5)
print(str6)
# Out:
# 안녕하세요
# 안녕하세요 "홍길동" 이라고 합니다
# 안녕하세요 "홍길동" 이라고 합니다
# 1.
# 여러 줄을
# 작성합니다.
# 2.
# 여러 줄을
# 작성합니다.
# 3.
# 여러 줄을
# 작성합니다

# %% [markdown]
# <table style="float:left">
# <thead>
# <tr>
# <th>코드</th>
# <th>설명</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>\n</code></td>
# <td><mark>문자열 안에서 줄을 바꿀 때 사용</mark></td>
# </tr>
# <tr>
# <td><code>\t</code></td>
# <td>문자열 사이에 탭 간격을 줄 때 사용</td>
# </tr>
# <tr>
# <td><code>\\</code></td>
# <td><code>\</code>를 그대로 표현할 때 사용</td>
# </tr>
# <tr>
# <td><code>\'</code></td>
# <td>작은따옴표(')를 그대로 표현할 때 사용</td>
# </tr>
# <tr>
# <td><code>\"</code></td>
# <td>큰따옴표(")를 그대로 표현할 때 사용</td>
# </tr>
# <tr>
# <td><code>\r</code></td>
# <td>캐리지 리턴(줄 바꿈 문자, 커서를 현재 줄의 가장 앞으로 이동)</td>
# </tr>
# <tr>
# <td><code>\f</code></td>
# <td>폼 피드(줄 바꿈 문자, 커서를 현재 줄의 다음 줄로 이동)</td>
# </tr>
# <tr>
# <td><code>\a</code></td>
# <td>벨 소리(출력할 때 PC 스피커에서 '삑' 소리가 난다)</td>
# </tr>
# <tr>
# <td><code>\b</code></td>
# <td>백 스페이스</td>
# </tr>
# <tr>
# <td><code>\000</code></td>
# <td>널 문자</td>
# </tr>
# </tbody>
# </table>

# %%
# 문자열 길이 구하기
a = "Life is too short"
print(a+"는",str(len(a)) + "자 입니다")
# Out:
# Life is too short는 17자 입니다

# %%
# 문자열 인덱싱
a = "Life is too short, You need Python"
print(a[0])
# Out:
# L

# %%
# 인덱싱을 이용한 house 만들기
print(a[13] + a[9] + a[-13] + a[12] + a[3])
# Out:
# house

# %%
# 문자열 슬라이싱, <= ~ <
a = "Life is too short, You need Python"
print(a[:4])
print(a[:4:2])
print(a[12:17])
print(a[19:])
# Out:
# Life
# Lf
# short
# You need Python

# %%
a = "20230331Rainy"
date = a[:8]
weather = a[8:]
print(date)
print(weather)
# Out:
# 20230331
# Rainy

# %%
## 문자열 불변
a = "Pithon"
a[1]
#a[1] = 'y'
a[:1] + 'y' + a[2:]
# Out:
# 'Python'

# %%
# 문제
today = "20260203오늘은쌀쌀하다"
# 목표값
print("2026년 2월 3일 오늘은 쌀쌀하다")
result = today[0:4] + "년 " + today[5] + "월 " + today[7] + "일 " + today[-7:-4] + " " + today[-4:]
print(result)
# Out:
# 2026년 2월 3일 오늘은 쌀쌀하다
# 2026년 2월 3일 오늘은 쌀쌀하다

# %%
# 테스트
import time as t
# print(dir(t))

# %%
print(req.__doc__)

# %%
# 응용
import requests as req
url1 = "https://blog.naver.com/pshhh9301/224169218126"
print(req.get(url1))
res = req.get(url1).text
# print(res)
print(res[res.find("쇠버랜드"):res.find("</title>")])
# Out:
# <Response [200]>
# 쇠버랜드의 헬스 이야기 : 네이버 블로그

# %%
# 문제
import requests as req
url2 = "https://v.daum.net/v/20260203120206039"
res = req.get(url2).text
print(res[res.find("오영석 박사는 "):res.find('"이라며 "대형 부품 제조를')])
# Out:
# 오영석 박사는 "앞으로 고내열 수지와 결합해 적정 온도를 500℃ 수준까지 끌어올리고, 실제 부품 환경에서 신뢰성을 검증할 계획

# %%
#문제
import requests as req
from datetime import date

bitUrl = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
wonUrl = "https://m.search.naver.com/p/csearch/content/qapirender.nhn?key=calculator&pkid=141&q=%ED%99%98%EC%9C%A8&where=m&u1=keb&u6=standardUnit&u7=0&u3=USD&u4=KRW&u8=down&u2=1"

bitRes = req.get(bitUrl).text
wonRes = req.get(wonUrl).text

bit = wonRes[wonRes.rfind("value", 2)+10:wonRes.rfind("value", 2)+15]
bit = int(bit.replace(',', ''))
won = format(bit * int(bitRes[29:34]), ',')

print(won + "원")
# Out:
# 1466
# 103,791,334원

# %% [markdown]
# ### 1.4.1 문자열 포매팅

# %%
# 문자열 포매팅, 대입
app = 3
print("나는 사과를 %d개 먹었다" % app)
# Out:
# 나는 사과를 3개 먹었다

# %%
print("나는 사과를 %s개 먹었다" % '3')
# Out:
# 나는 사과를 3개 먹었다

# %%
inp = input("몇 개인지 입력하세요")
print("나는 사과를 %d개 먹었다" % (int(inp) * 10))
# Out:
# 몇 개인지 입력하세요 13
# 나는 사과를 130개 먹었다

# %%
# 문자열 포매팅, 2개 이상의 값 넣기
won = int(input("가격: "))
ea = int(input("개수: "))
print("나는 %d원짜리 사과를 %d개 먹었다. 총 비용은 %d원이다." %(won, ea, won*ea))
# Out:
# 가격:  2000
# 개수:  2
# 나는 2000원짜리 사과를 2개 먹었다. 총 비용은 4000원이다.

# %%
print("%o" %123)
print("%f" %12.3)
# Out:
# 173
# 12.300000

# %% [markdown]
# <table style="float:left">
# <thead>
# <tr>
# <th>코드</th>
# <th>설명</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><mark>%s</mark></td>
# <td><mark>문자열(String)</mark></td>
# </tr>
# <tr>
# <td>%c</td>
# <td>문자 1개(character)</td>
# </tr>
# <tr>
# <td><mark>%d</mark></td>
# <td><mark>정수(Integer)</mark></td>
# </tr>
# <tr>
# <td><mark>%f</mark></td>
# <td><mark>부동소수(floating-point)</mark></td>
# </tr>
# <tr>
# <td>%o</td>
# <td>8진수</td>
# </tr>
# <tr>
# <td>%x</td>
# <td>16진수</td>
# </tr>
# <tr>
# <td>%%</td>
# <td>Literal % (문자 <code>%</code> 자체)</td>
# </tr>
# </tbody>
# </table>

# %%
# 문자열
print("%20s" % '12.34 문자표현')
# 정수
print("%-10d" % 12.34)
# 부동소수점
print("%f" % 12.34)
# %%표기
print("한국에 산은 %d%% 정도 있습니다" % 70)
# Out:
#           12.34 문자표현
# <class 'str'>
# 12.340000
# 한국에 산은 70% 정도 있습니다

# %% [markdown]
# #### 1.4.1.1 문자열 포맷코드

# %% [markdown]
# ![a](https://static.wikidocs.net/images/page/13/02_2_formating3.png)

# %%
# 소수점 표현
print("%.2f" % 3.141592)
print("%10.2f" % 3.141592)
print("%-10.2f" % 3.141592)
print("%-10.2f뒤에붙음" % 3.141592)
# Out:
# 3.14
#       3.14
# 3.14
# 3.14      뒤에붙음

# %% [markdown]
# ### 1.4.2 format 함수를 사용한 포매팅

# %%
# 숫자값을 가진 변수로 대입
s = "five"
ss = "I eat {0} apples".format(s)
print(ss, type(ss))
# Out:
# I eat five apples <class 'str'>

# %%
# 2개 이상 값 넣기
s = "five"
e = 7
ss = "I ate {0} apples, so I was sick for {1} days".format(s, e)
print(ss, type(ss))
# Out:
# I ate five apples, so I was sick for 7 days <class 'str'>

# %%
sss = "I ate {0} apples, so I was sick for {day} days".format(10, day=3)
print(sss)
# Out:
# I ate 10 apples, so I was sick for 3 days

# %%
# 왼쪽 정렬
print("{0:<10}".format("hi"))
# 오른쪽 정렬
print("{0:>10}".format("hi"))
# 가운데 정렬
print("{0:^10}".format("hi"))
# Out:
# hi
#         hi
#     hi

# %%
# 응용
re = "{0:*^18}".format("영수증")
print("="*20 + "\n" + re + "\n" + "="*20)
# Out:
# ...
# *******영수증********
# ...

# %%
# input 으로 개수를 입력받아
# 한 잔에 2500원인 아이스 아메리카노와 3800원인 라떼를 계산한 영수증을 출력
# 예
'''
=====================
        영수증
=====================
       아아 7잔
       라떼 4잔

---------------------
     아아 17500원
     라떼 15200원
>>> 총 가격:  32700원
=====================
'''
aaEa = input("아이스 아메리카노 개수를 입력해주세요")
latteEa = input("라떼 개수를 입력해주세요")

print("=====================\n\t영수증\n=====================")
print("       아아 {0}잔".format(aaEa))
print("       라떼 {0}잔".format(latteEa))

aaPrice = 2500 * int(aaEa)
lattePrice = 3800 * int(latteEa)
print("\n---------------------")
print("     아아 {0}원".format(aaPrice))
print("     라떼 {0}원".format(lattePrice))
print(">>> 총 가격:  {0}원".format(aaPrice + lattePrice))
print("=====================")
# Out:
# 아이스 아메리카노 개수를 입력해주세요 7
# 라떼 개수를 입력해주세요 4
# ...
# 	영수증
# ...
#        아아 7잔
#        라떼 4잔
#
# ---------------------
#      아아 17500원
#      라떼 15200원
# >>> 총 가격:  32700원
# ...

# %% [markdown]
# ### 1.4.3 f문자열 포매팅

# %%
name = "홍길동"
age  = 30
print(f"나의 이름은 {name:=^11}이고, 나이는 {age+1} 입니다.")
# Out:
# 나의 이름은 ====홍길동====이고, 나이는 31 입니다.

# %%
d = {'name':'홍길동', 'age':30}
print(f"나의 이름은 {(d['name']):=^11}이고, 나이는 {d['age']+1} 입니다.")
# Out:
# 나의 이름은 ====홍길동====이고, 나이는 31 입니다.

# %%
# f문자열을 사용하여 세자리 콤마 찍기
f"{140000000:,}"
# Out:
# '140,000,000'

# %% [markdown]
# ### 1.4.4 문자열 관련 함수들

# %%
# 문자 개수 세기
a = 'hobby'
b = 'appleppp'
print(a.count("b"))
print(b.count('p'))
# Out:
# 2
# 5

# %%
# find - 위치 알려주기1
a = "Python is the best choice"
print(a.find('P'))
print(a.find('b'))
print(a.find('x'))
# Out:
# 0
# 14
# -1

# %%
# index - 위치 알려주기2
a = "Python is the best choice"
print(a.index('P'))
print(a.index('b'))
# print(a.index('x'))
# Out:
# 0
# 14

# %%
# join - 문자열 삽입
ss = 'abcdefg'
ss = "*".join(ss)
print(ss)
# Out:
# a*b*c*d*e*f*g

# %%
nn = '123456789'
nn = "빠 ".join(nn) + "빠"
print(nn)
# Out:
# 1빠 2빠 3빠 4빠 5빠 6빠 7빠 8빠 9빠

# %%
# upper - 소문자->대문자
a = "Python is the best choice"
a = a.upper()
print(a)

# lower - 대문자->소문자
a = a.lower()
print(a)

a = "Python is the best choice"
a = a[0] + a[1:].lower()
print(a)
# Out:
# PYTHON IS THE BEST CHOICE
# python is the best choice
# Python is the best choice

# %%
ss = f"{'hi':^12}"
print(ss)
ss = ss.lstrip()
print(ss)
ss = ss.rstrip()
print(ss)
# Out:
#      hi
# hi
# hi

# %%
a = "hello"
b = "hello"
print(a == b)
# Out:
# True

# %%
# replace - 문자열 바꾸기
a = 'Life is too short'
a = a.replace("Life", "Time")
print(a)
# Out:
# Time is too short

# %%
# split - 문자열 나누기
a = 'Life is too short'
a = a.split()
print(a)

b = 'a:b:c:d:f'
b = b.split(":")
print(b)

# 문제
# BaNaNa -> banana -> c = b*n*a*N*a -> ['b', 'a', 'n', 'a', 'n', 'a']
ba = 'BaNaNa'
ba = ba.lower()
print(ba)
ba = "*".join(ba)
print(ba)
ba = ba.split("*")
print(ba)
# Out:
# ['Life', 'is', 'too', 'short']
# ['a', 'b', 'c', 'd', 'f']
# banana
# b*a*n*a*n*a
# ['b', 'a', 'n', 'a', 'n', 'a']

# %%
# isalpha - 문자열이 알파벳으로만 구성되어 있는지 확인
s = 'Life is too short'
s = s.replace(" ", "").isalpha()
print(s)
# Out:
# True

# %%
# isdigit - 문자열이 숫자로만 구성되어 있는지 확인
n = "123456"
s = n.isdigit()
print(n)
# Out:
# 123456
